# %%
# Example 6: Using Matplotlib to Import Image Data as a NumPy Array

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# img = mpimg.imread('Desktop/chris.jpeg')
# img = mpimg.imread('darkreader-mascot.svg')  # Cannot identify svg
img = mpimg.imread('4629794.jpeg')
imgplot = plt.imshow(img)

plt.show()
